# %% [markdown]
# Install dependencies

# %%
pip install langchain langchain-groq

# %% [markdown]
# Upload files

# %%
from google.colab import files
uploaded = files. upload()
# Out:
#      <input type="file" id="files-82935115-ef7f-4470-a129-9bb95b38d9c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82935115-ef7f-4470-a129-9bb95b38d9c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# import modules

# %%
from pandasai import SmartDataframe
from langchain_groq import ChatGroq
import pandas as pd
import os
from google.colab import userdata

# %%
os.environ["GROQ_API_KEY"]= userdata.get("GROQ_API_KEY")

# %% [markdown]
# **Data Preparation:**

# %%
morning_df = pd.read_csv('/content/Morning-28th-June.csv')
afternoon_df = pd.read_csv('/content/Afternoon-28th-June.csv')
evening_df = pd.read_csv('/content/Evening-28th-June.csv')


print("Morning Batch Data:")
morning_df.head()
# Out:
# Morning Batch Data:
#              Name (Original Name)       User Email               Join Time  \
# 0  Krishna Singh (Akshita Roshan)  akshita@agie.ai  06/28/2024 09:52:45 AM
# 1                    Chetan Kumar              NaN  06/28/2024 09:52:52 AM
# 2                  Akshita Roshan              NaN  06/28/2024 09:52:52 AM
# 3               Kshitij Tardalkar              NaN  06/28/2024 09:52:56 AM
# 4                    Chetan Kumar              NaN  06/28/2024 09:52:57 AM
#
#                Leave Time  Duration (Minutes) Guest In Waiting Room
# 0  06/28/2024 10:17:06 AM                  25    No              No
# 1  06/28/2024 09:52:57 AM                   1   Yes             Yes
# 2  06/28/2024 09:53:08 AM                   1   Yes             Yes
# 3  06/28/2024 09:56:52 AM                   4   Yes             Yes
# 4  06/28/2024 10:16:12 AM                  24   Yes              No

# %%
print("\nAfternoon Batch Data:")
afternoon_df.head()
# Out:
# Afternoon Batch Data:
#             Name (Original Name)       User Email               Join Time  \
# 0  Krisha Singh (Akshita Roshan)  akshita@agie.ai  06/28/2024 03:57:40 PM
# 1                         Tanuja              NaN  06/28/2024 03:57:49 PM
# 2                      Yash Goel              NaN  06/28/2024 03:57:53 PM
# 3                        Darshan              NaN  06/28/2024 03:57:53 PM
# 4                    sneha pawar              NaN  06/28/2024 03:57:56 PM
#
#                Leave Time  Duration (Minutes) Guest In Waiting Room
# 0  06/28/2024 04:19:20 PM                  22    No              No
# 1  06/28/2024 03:58:04 PM                   1   Yes             Yes
# 2  06/28/2024 03:58:09 PM                   1   Yes             Yes
# 3  06/28/2024 03:58:09 PM                   1   Yes             Yes
# 4  06/28/2024 03:58:20 PM                   1   Yes             Yes

# %%
print("\nEvening Batch Data:")
evening_df.head()
# Out:
# Evening Batch Data:
#              Name (Original Name)       User Email               Join Time  \
# 0                     Agrima Jain              NaN  06/28/2024 08:56:01 PM
# 1          AIML-19-SHOUNAK_SARKAR              NaN  06/28/2024 08:56:04 PM
# 2                  Akshita Roshan              NaN  06/28/2024 08:56:07 PM
# 3            Revanth Christober M              NaN  06/28/2024 08:56:08 PM
# 4  Krishna Singh (Akshita Roshan)  akshita@agie.ai  06/28/2024 08:56:10 PM
#
#                Leave Time  Duration (Minutes) Guest  \
# 0  06/28/2024 08:59:15 PM                   4   Yes
# 1  06/28/2024 08:57:19 PM                   2   Yes
# 2  06/28/2024 08:57:20 PM                   2   Yes
# 3  06/28/2024 08:57:24 PM                   2   Yes
# 4  06/28/2024 09:19:37 PM                  24    No
#
#   Recording Disclaimer Response In Waiting Room
# 0                   No Response              No
# 1                   No Response             Yes
# ...

# %% [markdown]
# **Data Grouping and Summarization:**

# %%
morning_grouped = morning_df.groupby('Name (Original Name)').sum().reset_index()
afternoon_grouped = afternoon_df.groupby('Name (Original Name)').sum().reset_index()
evening_grouped = evening_df.groupby('Name (Original Name)').sum().reset_index()
# Out:
# <ipython-input-20-842427192e20>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   morning_grouped = morning_df.groupby('Name (Original Name)').sum().reset_index()
# <ipython-input-20-842427192e20>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   afternoon_grouped = afternoon_df.groupby('Name (Original Name)').sum().reset_index()
# <ipython-input-20-842427192e20>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# ...

# %%
morning_grouped
# Out:
#                          Name (Original Name)  Duration (Minutes)
# 0                00003121002_Sarath Rajendran                   4
# 1                    16010320032_Soham_Khadke                  98
# 2                                    17 SUMEN                   2
# 3                    1AM20AI015 Hareram mahto                   6
# 4                     2005969 SRIKAR REDDY T.                   4
# ..                                        ...                 ...
# 147                       sirisha sribhashyam                  96
# 148                              sushain devi                  15
# 149  tera sribindhu (2005969 SRIKAR REDDY T.)                  44
# 150                              v.karthikeya                   2
# 151                                  سيد سامي                  20
#
# [152 rows x 2 columns]

# %%
afternoon_grouped
# Out:
#                  Name (Original Name)  Duration (Minutes)
# 0                 200636_Nikhil Singh                   1
# 1                  2255 _Tanisha Basu                  77
# 2                              Aayush                  87
# 3   Aayush (Aayush Gulati (B21BB002))                   9
# 4                      Abhishek Reddy                  14
# ..                                ...                 ...
# 63                          adithia v                  98
# 64                             pratik                  98
# 65                      satwik tiwari                   5
# 66                      shivam pandey                  86
# 67                        sneha pawar                  95
#
# [68 rows x 2 columns]

# %%
evening_grouped
# Out:
#        Name (Original Name)  Duration (Minutes)
# 0         '-Meet Vaghasiya-                  18
# 1              091101 10101                   1
# 2         4191_MahimaMaurya                  36
# 3          445 Sagar Bokade                  75
# 4    AIML-19-SHOUNAK_SARKAR                  88
# ..                      ...                 ...
# 156       Yashraj Choudhary                  71
# 157          lakshay sharma                  37
# 158            rinkesh sahu                  48
# 159       samruddhi shirode                  50
# 160          sharib mallick                  64
#
# [161 rows x 2 columns]

# %%
morning_grouped['Date'] = '2024-06-28'
afternoon_grouped['Date'] = '2024-06-28'
evening_grouped['Date'] = '2024-06-28'

# %%
morning_grouped.head()
# Out:
#            Name (Original Name)  Duration (Minutes)        Date
# 0  00003121002_Sarath Rajendran                   4  2024-06-28
# 1      16010320032_Soham_Khadke                  98  2024-06-28
# 2                      17 SUMEN                   2  2024-06-28
# 3      1AM20AI015 Hareram mahto                   6  2024-06-28
# 4       2005969 SRIKAR REDDY T.                   4  2024-06-28

# %%
afternoon_grouped.head()
# Out:
#                 Name (Original Name)  Duration (Minutes)        Date
# 0                200636_Nikhil Singh                   1  2024-06-28
# 1                 2255 _Tanisha Basu                  77  2024-06-28
# 2                             Aayush                  87  2024-06-28
# 3  Aayush (Aayush Gulati (B21BB002))                   9  2024-06-28
# 4                     Abhishek Reddy                  14  2024-06-28

# %%
evening_grouped.head()
# Out:
#      Name (Original Name)  Duration (Minutes)        Date
# 0       '-Meet Vaghasiya-                  18  2024-06-28
# 1            091101 10101                   1  2024-06-28
# 2       4191_MahimaMaurya                  36  2024-06-28
# 3        445 Sagar Bokade                  75  2024-06-28
# 4  AIML-19-SHOUNAK_SARKAR                  88  2024-06-28

# %%
def chat_with_csv(df,query):
    # Initialize LLM
    llm = ChatGroq(model="llama3-70b-8192")
    # Initialize SmartDataframe with DataFrame and LLM configuration
    pandas_ai = SmartDataframe(df, config={"llm": llm})
    # Chat with the DataFrame using the provided query
    result = pandas_ai.chat(query)
    return result

# %% [markdown]
# **Total Duration Calculation**

# %%
total_duration=[]

# %% [markdown]
# evening_grouped

# %%
total_duration.append(chat_with_csv(evening_grouped,"Calculate the total duration of attendance "))
total_duration[0]
# Out:
# 10022

# %% [markdown]
# afternoon_grouped

# %%
total_duration.append(chat_with_csv(afternoon_grouped,"Calculate the total duration of attendance "))
total_duration[1]
# Out:
# 4783

# %% [markdown]
# morning_grouped

# %%
total_duration.append(chat_with_csv(morning_grouped,"Calculate the total duration of attendance "))
total_duration[2]
# Out:
# 10141

# %% [markdown]
# **Average Duration Calculation**

# %%
average_duration=[]

# %% [markdown]
# evening_grouped

# %%
average_duration.append(chat_with_csv(evening_grouped,"Calculate the average duration of attendance"))
average_duration[0]
# Out:
# 62.24844720496895

# %% [markdown]
# afternoon_grouped

# %%
average_duration.append(chat_with_csv(afternoon_grouped,"Calculate the average duration of attendance"))
average_duration[1]
# Out:
# 70.33823529411765

# %% [markdown]
# morning_grouped

# %%
average_duration.append(chat_with_csv(morning_grouped,"Calculate the average duration of attendance"))
average_duration[2]
# Out:
# 66.71710526315789

# %% [markdown]
# **Standard Deviation Calculation**

# %%
std_duration=[]

# %% [markdown]
# evening_grouped

# %%
std_duration.append(chat_with_csv(evening_grouped,"Calculate the standard deviation of attendance duration"))
std_duration[0]
# Out:
# 28.31083699535652

# %% [markdown]
# afternoon_grouped

# %%
std_duration.append(chat_with_csv(afternoon_grouped,"Calculate the standard deviation of attendance duration"))
std_duration[1]
# Out:
# 37.907243718022784

# %% [markdown]
# morning_grouped

# %%
std_duration.append(chat_with_csv(morning_grouped,"Calculate the standard deviation of attendance duration"))
std_duration[2]
# Out:
# 34.070441302804795

# %% [markdown]
# **Percentage Calculation**

# %%
percentages=[]

# %% [markdown]
# evening_grouped

# %%
percentages.append(chat_with_csv(evening_grouped,"Calculate the percentage of users who attended more than the average duration"))
percentages[0]
# Out:
# 66.45962732919256

# %% [markdown]
# afternoon_grouped

# %%
percentages.append(chat_with_csv(afternoon_grouped,"Calculate the percentage of users who attended more than the average duration"))
percentages[1]
# Out:
# 66.17647058823529

# %% [markdown]
# morning_grouped

# %%
percentages.append(chat_with_csv(morning_grouped,"Calculate the percentage of users who attended more than the average duration"))
percentages[2]
# Out:
# 64.47368421052632

# %% [markdown]
# **Duration Buckets Distribution**

# %% [markdown]
# evening_grouped

# %%
chat_with_csv(evening_grouped,"Plot a histogram ")
# Out:
# '/content/exports/charts/temp_chart.png'

# %% [markdown]
# afternoon_grouped

# %%
chat_with_csv(afternoon_grouped,"Plot a histogram ")
# Out:
# '/content/exports/charts/temp_chart.png'

# %% [markdown]
# morning_grouped

# %%
chat_with_csv(morning_grouped,"Plot a histogram ")
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
len(total_duration),len(average_duration),len(std_duration),len(percentages)
# Out:
# (3, 3, 3, 3)

# %% [markdown]
# **Comparative Analysis**

# %%
comparison_df = pd.DataFrame({
    'Batch': ['evening', 'Afternoon', 'morning'],
    'Total Duration': total_duration,
    'Average Duration': average_duration,
    'Standard Deviation': std_duration,
    'Percentage Above Avg': percentages
})

# %%
comparison_df
# Out:
#        Batch  Total Duration  Average Duration  Standard Deviation  \
# 0    evening           10022         62.248447           28.310837
# 1  Afternoon            4783         70.338235           37.907244
# 2    morning           10141         66.717105           34.070441
#
#    Percentage Above Avg
# 0             66.459627
# 1             66.176471
# 2             64.473684

# %%
chat_with_csv(comparison_df," Compare the total durations of users attending more than the average duration across all three morning,afternoon and evening batches")
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
chat_with_csv(comparison_df," Compare the average duration of users attending more than the average duration across all three morning,afternoon and evening batches")
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
chat_with_csv(comparison_df," Compare the standard deviation, and percentage of users attending more than the average duration across all three batches")
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
comparison_df
# Out:
#        Batch  Total Duration  Average Duration  Standard Deviation  \
# 0    evening           10022         62.248447           28.310837
# 1  Afternoon            4783         70.338235           37.907244
# 2    morning           10141         66.717105           34.070441
#
#    Percentage Above Avg
# 0             66.459627
# 1             66.176471
# 2             64.473684

# %% [markdown]
# **Report Generation:**

# %%
report=chat_with_csv(comparison_df,"""Generate detailed summary reports for each batch (morning, afternoon, evening)""")

# %%
report
# Out:
#        Batch                                     Summary Report
# 0    morning  Batch: evening\nTotal Duration: 10022\nAverage...
# 1    evening  Batch: Afternoon\nTotal Duration: 4783\nAverag...
# 2  Afternoon  Batch: morning\nTotal Duration: 10141\nAverage...

# %%
print(report['Summary Report'][0])
print("*"*50)
print(report['Summary Report'][1])
print("*"*50)
print(report['Summary Report'][2])
# Out:
# Batch: evening
# Total Duration: 10022
# Average Duration: 62.25
# Standard Deviation: 28.31
# Percentage Above Avg: 66.46%
#
# **************************************************
# Batch: Afternoon
# Total Duration: 4783
# Average Duration: 70.34
# Standard Deviation: 37.91
# Percentage Above Avg: 66.18%
#
# **************************************************
# Batch: morning
# Total Duration: 10141
# Average Duration: 66.72
# Standard Deviation: 34.07
# Percentage Above Avg: 64.47%

# %% [markdown]
# **combined summary report**

# %%
report=chat_with_csv(comparison_df,"""Generate a combined summary report comparing all three batches in proper frofessional manner such that each thing specified seprately.""")
print(report)
# Out:
# Total Duration Comparison:
# Afternoon: 10022
# Evening: 4783
# Morning: 10141
#
# Average Duration Comparison:
# Afternoon: 62.25
# Evening: 70.34
# Morning: 66.72
#
# Standard Deviation Comparison:
# Afternoon: 28.31
# Evening: 37.91
# Morning: 34.07
#
# Percentage Above Avg Comparison:
# Afternoon: 66.46%
# Evening: 66.18%
# Morning: 64.47%
